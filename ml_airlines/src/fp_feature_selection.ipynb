# %%
FEATURES_AIR = [
'YEAR', # must include time here because DEP_TIME is full of na values
'QUARTER',
'MONTH',
'DAY_OF_MONTH',
'DAY_OF_WEEK',

'FL_DATE',
'OP_UNIQUE_CARRIER', 
'OP_CARRIER_AIRLINE_ID', 
# 'OP_CARRIER',
'TAIL_NUM', # tail number is unique to the plane; kept because some plane might experience faults more frequently than others
'OP_CARRIER_FL_NUM', # flight number is unique to the flight

'ORIGIN_AIRPORT_ID',
'ORIGIN_AIRPORT_SEQ_ID', # airports can change name and coordinates over time
# 'ORIGIN_CITY_MARKET_ID',
'ORIGIN', # required for time conversion
# 'ORIGIN_CITY_NAME',
'ORIGIN_STATE_ABR',
# 'ORIGIN_STATE_FIPS',
# 'ORIGIN_STATE_NM',
# 'ORIGIN_WAC',

'DEST_AIRPORT_ID',
'DEST_AIRPORT_SEQ_ID',
# 'DEST_CITY_MARKET_ID',
'DEST', # required for time conversion
# 'DEST_CITY_NAME',
'DEST_STATE_ABR',
# 'DEST_STATE_FIPS',
# 'DEST_STATE_NM',
# 'DEST_WAC',

'CRS_DEP_TIME', # scheduled time, local time
'DEP_TIME', # lots of null; possible due to cancelled flights
'DEP_DELAY',
'DEP_DELAY_NEW',
'DEP_DEL15',
'DEP_DELAY_GROUP', # 15 minutes interval
'DEP_TIME_BLK', # hourly interval

'TAXI_OUT',
# 'WHEELS_OFF',
# 'WHEELS_ON',
'TAXI_IN',

'CRS_ARR_TIME',
'ARR_TIME',
'ARR_DELAY',
'ARR_DELAY_NEW',
'ARR_DEL15',
'ARR_DELAY_GROUP',
'ARR_TIME_BLK',

'CANCELLED',
# 'CANCELLATION_CODE',
'DIVERTED',
'CRS_ELAPSED_TIME',
'ACTUAL_ELAPSED_TIME',
'AIR_TIME',
'FLIGHTS',
'DISTANCE',
'DISTANCE_GROUP',

'CARRIER_DELAY',
'WEATHER_DELAY',
'NAS_DELAY',
'SECURITY_DELAY',
'LATE_AIRCRAFT_DELAY',

# 'FIRST_DEP_TIME',
# 'TOTAL_ADD_GTIME',
# 'LONGEST_ADD_GTIME',

# 'DIV_AIRPORT_LANDINGS',
# 'DIV_REACHED_DEST',
# 'DIV_ACTUAL_ELAPSED_TIME',
# 'DIV_ARR_DELAY',
# 'DIV_DISTANCE',
# 'DIV1_AIRPORT',
# 'DIV1_AIRPORT_ID',
# 'DIV1_AIRPORT_SEQ_ID',
# 'DIV1_WHEELS_ON',
# 'DIV1_TOTAL_GTIME',
# 'DIV1_LONGEST_GTIME',
# 'DIV1_WHEELS_OFF',
# 'DIV1_TAIL_NUM',
# 'DIV2_AIRPORT',
# 'DIV2_AIRPORT_ID',
# 'DIV2_AIRPORT_SEQ_ID',
# 'DIV2_WHEELS_ON',
# 'DIV2_TOTAL_GTIME',
# 'DIV2_LONGEST_GTIME',
# 'DIV2_WHEELS_OFF',
# 'DIV2_TAIL_NUM',
# 'DIV3_AIRPORT',
# 'DIV3_AIRPORT_ID',
# 'DIV3_AIRPORT_SEQ_ID',
# 'DIV3_WHEELS_ON',
# 'DIV3_TOTAL_GTIME',
# 'DIV3_LONGEST_GTIME',
# 'DIV3_WHEELS_OFF',
# 'DIV3_TAIL_NUM',
# 'DIV4_AIRPORT',
# 'DIV4_AIRPORT_ID',
# 'DIV4_AIRPORT_SEQ_ID',
# 'DIV4_WHEELS_ON',
# 'DIV4_TOTAL_GTIME',
# 'DIV4_LONGEST_GTIME',
# 'DIV4_WHEELS_OFF',
# 'DIV4_TAIL_NUM',
# 'DIV5_AIRPORT',
# 'DIV5_AIRPORT_ID',
# 'DIV5_AIRPORT_SEQ_ID',
# 'DIV5_WHEELS_ON',
# 'DIV5_TOTAL_GTIME',
# 'DIV5_LONGEST_GTIME',
# 'DIV5_WHEELS_OFF',
# 'DIV5_TAIL_NUM'
]

FEATURES_WEATHER = [
'STATION',
'DATE',
# 'SOURCE',
'LATITUDE',
'LONGITUDE',
# 'ELEVATION',
'NAME',
# 'REPORT_TYPE',
# 'CALL_SIGN',
# 'QUALITY_CONTROL',
'WND',
'CIG',
'VIS',
'TMP',
'DEW',
'SLP',
# 'AW1',
# 'GA1',
# 'GA2',
# 'GA3',
# 'GA4',
# 'GE1',
# 'GF1',
# 'KA1',
# 'KA2',
# 'MA1',
# 'MD1',
# 'MW1',
# 'MW2',
# 'OC1',
# 'OD1',
# 'OD2',
# 'REM',
# 'EQD',
# 'AW2',
# 'AX4',
# 'GD1',
# 'AW5',
# 'GN1',
# 'AJ1',
# 'AW3',
# 'MK1',
# 'KA4',
# 'GG3',
# 'AN1',
# 'RH1',
# 'AU5',
# 'HL1',
# 'OB1',
# 'AT8',
# 'AW7',
# 'AZ1',
# 'CH1',
# 'RH3',
# 'GK1',
# 'IB1',
# 'AX1',
# 'CT1',
# 'AK1',
# 'CN2',
# 'OE1',
# 'MW5',
# 'AO1',
# 'KA3',
# 'AA3',
# 'CR1',
# 'CF2',
# 'KB2',
# 'GM1',
# 'AT5',
# 'AY2',
# 'MW6',
# 'MG1',
# 'AH6',
# 'AU2',
# 'GD2',
# 'AW4',
# 'MF1',
# 'AA1',
# 'AH2',
# 'AH3',
# 'OE3',
# 'AT6',
# 'AL2',
# 'AL3',
# 'AX5',
# 'IB2',
# 'AI3',
# 'CV3',
# 'WA1',
# 'GH1',
# 'KF1',
# 'CU2',
# 'CT3',
# 'SA1',
# 'AU1',
# 'KD2',
# 'AI5',
# 'GO1',
# 'GD3',
# 'CG3',
# 'AI1',
# 'AL1',
# 'AW6',
# 'MW4',
# 'AX6',
# 'CV1',
# 'ME1',
# 'KC2',
# 'CN1',
# 'UA1',
# 'GD5',
# 'UG2',
# 'AT3',
# 'AT4',
# 'GJ1',
# 'MV1',
# 'GA5',
# 'CT2',
# 'CG2',
# 'ED1',
# 'AE1',
# 'CO1',
# 'KE1',
# 'KB1',
# 'AI4',
# 'MW3',
# 'KG2',
# 'AA2',
# 'AX2',
# 'AY1',
# 'RH2',
# 'OE2',
# 'CU3',
# 'MH1',
# 'AM1',
# 'AU4',
# 'GA6',
# 'KG1',
# 'AU3',
# 'AT7',
# 'KD1',
# 'GL1',
# 'IA1',
# 'GG2',
# 'OD3',
# 'UG1',
# 'CB1',
# 'AI6',
# 'CI1',
# 'CV2',
# 'AZ2',
# 'AD1',
# 'AH1',
# 'WD1',
# 'AA4',
# 'KC1',
# 'IA2',
# 'CF3',
# 'AI2',
# 'AT1',
# 'GD4',
# 'AX3',
# 'AH4',
# 'KB3',
# 'CU1',
# 'CN4',
# 'AT2',
# 'CG1',
# 'CF1',
# 'GG1',
# 'MV2',
# 'CW1',
# 'GG4',
# 'AB1',
# 'AH5',
# 'CN3', 
]

# do not remove YEAR and CANCELLED
FEATURES_TRAIN = [
 'YEAR',
#  'QUARTER',
 'MONTH',
 'DAY_OF_MONTH',
 'DAY_OF_WEEK',
#  'FL_DATE',
#  'OP_UNIQUE_CARRIER',
 'OP_CARRIER_AIRLINE_ID',
 'TAIL_NUM',
 'OP_CARRIER_FL_NUM',
 'ORIGIN_AIRPORT_ID',
#  'ORIGIN_AIRPORT_SEQ_ID',
#  'ORIGIN',
 'DEST_AIRPORT_ID',
#  'DEST_AIRPORT_SEQ_ID',
#  'DEST',
#  'CRS_DEP_TIME',
#  'DEP_TIME',
#  'DEP_DELAY_NEW',
 'DEP_DEL15',
 'DEP_DELAY_GROUP',
 'DEP_TIME_BLK',
#  'TAXI_OUT',
#  'TAXI_IN',
#  'CRS_ARR_TIME',
#  'ARR_TIME',
#  'ARR_DELAY_NEW',
#  'ARR_DEL15',
#  'ARR_DELAY_GROUP',
#  'ARR_TIME_BLK',
 'CANCELLED',
#  'DIVERTED',
#  'CRS_ELAPSED_TIME',
#  'ACTUAL_ELAPSED_TIME',
#  'AIR_TIME',
#  'FLIGHTS',
 'DISTANCE',
#  'DISTANCE_GROUP',
#  'CARRIER_DELAY',
#  'WEATHER_DELAY',
#  'NAS_DELAY',
#  'SECURITY_DELAY',
#  'LATE_AIRCRAFT_DELAY',
#  'ID',
#  'DEP_TIME_DT',
#  'ARR_TIME_DT',
#  'CRS_DEP_TIME_DT',
#  'CRS_ARR_TIME_DT',
#  'ORIGIN_TZ',
#  'DEST_TZ',
#  'DEP_TIME_UTC',
#  'ARR_TIME_UTC',
#  'CRS_DEP_TIME_UTC',
#  'CRS_ARR_TIME_UTC',
#  'CRS_DEP_TIME_UTC_HOUR',
#  'ORIGIN_W_STATION',
#  'ORIGIN_W_DATE',
 'ORIGIN_W_WND_DIR',
 'ORIGIN_W_WND_DIR_QLTY',
 'ORIGIN_W_WND_TYPE',
 'ORIGIN_W_WND_SPD',
 'ORIGIN_W_WND_SPD_QLTY',
 'ORIGIN_W_CIG_DIM',
 'ORIGIN_W_CIG_DIM_QLTY',
 'ORIGIN_W_CIG_DETCODE',
 'ORIGIN_W_CIG_CAVOK',
 'ORIGIN_W_VIS_DIM',
 'ORIGIN_W_VIS_DIM_QLTY',
 'ORIGIN_W_VIS_VAR',
 'ORIGIN_W_VIS_VAR_QLTY',
 'ORIGIN_W_TMP_DIM',
 'ORIGIN_W_TMP_QLTY',
 'ORIGIN_W_DEW_DIM',
 'ORIGIN_W_DEW_QLTY',
 'ORIGIN_W_SLP_DIM',
 'ORIGIN_W_SLP_QLTY',
 'ORIGIN_W_WEATHER_ERROR_FREE',
 'ORIGIN_W_DISTANCE',
#  'DEST_W_STATION',
#  'DEST_W_DATE',
 'DEST_W_WND_DIR',
 'DEST_W_WND_DIR_QLTY',
 'DEST_W_WND_TYPE',
 'DEST_W_WND_SPD',
 'DEST_W_WND_SPD_QLTY',
 'DEST_W_CIG_DIM',
 'DEST_W_CIG_DIM_QLTY',
 'DEST_W_CIG_DETCODE',
 'DEST_W_CIG_CAVOK',
 'DEST_W_VIS_DIM',
 'DEST_W_VIS_DIM_QLTY',
 'DEST_W_VIS_VAR',
 'DEST_W_VIS_VAR_QLTY',
 'DEST_W_TMP_DIM',
 'DEST_W_TMP_QLTY',
 'DEST_W_DEW_DIM',
 'DEST_W_DEW_QLTY',
 'DEST_W_SLP_DIM',
 'DEST_W_SLP_QLTY',
 'DEST_W_WEATHER_ERROR_FREE',
 'DEST_W_DISTANCE']

# doc: https://docs.databricks.com/notebooks/notebook-workflows.html
features = {'air':FEATURES_AIR, 'weather':FEATURES_WEATHER, 'train': FEATURES_TRAIN}
dbutils.notebook.exit(features)
# Out:
# {'air': ['YEAR', 'QUARTER', 'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'FL_DATE', 'OP_UNIQUE_CARRIER', 'OP_CARRIER_AIRLINE_ID', 'TAIL_NUM', 'OP_CARRIER_FL_NUM', 'ORIGIN_AIRPORT_ID', 'ORIGIN_AIRPORT_SEQ_ID', 'ORIGIN', 'DEST_AIRPORT_ID', 'DEST_AIRPORT_SEQ_ID', 'DEST', 'CRS_DEP_TIME', 'DEP_TIME', 'DEP_DELAY_NEW', 'DEP_DEL15', 'DEP_DELAY_GROUP', 'DEP_TIME_BLK', 'TAXI_OUT', 'TAXI_IN', 'CRS_ARR_TIME', 'ARR_TIME', 'ARR_DELAY_NEW', 'ARR_DEL15', 'ARR_DELAY_GROUP', 'ARR_TIME_BLK', 'CANCELLED', 'DIVERTED', 'CRS_ELAPSED_TIME', 'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'FLIGHTS', 'DISTANCE', 'DISTANCE_GROUP', 'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY'], 'weather': ['STATION', 'DATE', 'LATITUDE', 'LONGITUDE', 'NAME', 'WND', 'CIG', 'VIS', 'TMP', 'DEW', 'SLP'], 'train': ['YEAR', 'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'OP_CARRIER_AIRLINE_ID', 'TAIL_NUM', 'OP_CARRIER_FL_NUM', 'ORIGIN_AIRPORT_ID', 'DEST_AIRPORT_ID', 'DEP_DEL15', 'DEP_DELAY_GROUP', 'DEP_TIME_BLK', 'CAN
# ...
